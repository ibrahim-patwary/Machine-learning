# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("E:\jupyter notebook\Machine Learning\Encoding Techniques\Manual Encoding\Data set\Companies.csv")
df
# Out:
#     Customer_ID  Gender  Age  Annual Income (k$)  Spending score(1-100)  \
# 0             1    Male   19                  15                     39
# 1             2    Male   21                  15                     81
# 2             3  Female   20                  16                      6
# 3             4  Female   23                  16                     77
# 4             5  Female   31                  17                     40
# 5             6  Female   22                  17                     76
# 6             7  Female   35                  18                      6
# 7             8  Female   23                  18                     94
# 8             9    Male   64                  19                      3
# 9            10  Female   30                  19                     72
# 10           11    Male   33                  25                     67
#
#         Area
# 0     Dhaka
# 1   Rajshahi
# 2    Rangpur
# 3     Khulna
# 4     Dhaka
# 5     Khulna
# ...

# %%
df.isnull().sum()
# Out:
# Customer_ID              0
# Gender                   0
# Age                      0
# Annual Income (k$)       0
# Spending score(1-100)    0
# Area                     0
# dtype: int64

# %%
df["Area"].unique()
# Out:
# array(['Dhaka ', 'Rajshahi', 'Rangpur', 'Khulna', 'Chandpur'],
#       dtype=object)

# %%
df["Gender"].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df["Area"] = df["Area"].replace(['Dhaka ', 'Rajshahi', 'Rangpur', 'Khulna', 'Chandpur'],[1,2,3,4,7])

# %%
df["Gender"] = df["Gender"].replace(['Male', 'Female'],[1,0])

# %%
df
# Out:
#     Customer_ID  Gender  Age  Annual Income (k$)  Spending score(1-100)  Area
# 0             1       1   19                  15                     39     1
# 1             2       1   21                  15                     81     2
# 2             3       0   20                  16                      6     3
# 3             4       0   23                  16                     77     4
# 4             5       0   31                  17                     40     1
# 5             6       0   22                  17                     76     4
# 6             7       0   35                  18                      6     1
# 7             8       0   23                  18                     94     3
# 8             9       1   64                  19                      3     3
# 9            10       0   30                  19                     72     1
# 10           11       1   33                  25                     67     7
